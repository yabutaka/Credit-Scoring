# %%
import pandas as pd
import re

# %%
df_train = pd.read_csv("raw/train.csv")
df_test = pd.read_csv("raw/test.csv")

# %%
df = df_train

# %%
df_train.columns = pd.Series(df_train.columns).apply(lambda x: x.lower())

# %%
def create_camel_case(myString, seperator):
    lst = myString.split(seperator)
    if len(lst) < 2:
        return myString
    else:
        for i in range(len(lst)):
            if i != 0:
                lst[i] = lst[i][0].upper() + lst[i][1:]
        return ''.join(lst)

# %%
df.columns = pd.Series(df.columns).apply(create_camel_case, 
                              seperator = '_').apply(create_camel_case,
                              seperator = '.')

# %%
df.columns
# Out:
# Index(['uniqueid', 'disbursedAmount', 'assetCost', 'ltv', 'branchId',
#        'supplierId', 'manufacturerId', 'currentPincodeId', 'dateOfBirth',
#        'employmentType', 'disbursaldate', 'stateId', 'employeeCodeId',
#        'mobilenoAvlFlag', 'aadharFlag', 'panFlag', 'voteridFlag',
#        'drivingFlag', 'passportFlag', 'performCnsScore',
#        'performCnsScoreDescription', 'priNoOfAccts', 'priActiveAccts',
#        'priOverdueAccts', 'priCurrentBalance', 'priSanctionedAmount',
#        'priDisbursedAmount', 'secNoOfAccts', 'secActiveAccts',
#        'secOverdueAccts', 'secCurrentBalance', 'secSanctionedAmount',
#        'secDisbursedAmount', 'primaryInstalAmt', 'secInstalAmt',
#        'newAcctsInLastSixMonths', 'delinquentAcctsInLastSixMonths',
#        'averageAcctAge', 'creditHistoryLength', 'noOfInquiries',
#        'loanDefault'],
#       dtype='object')

# %%
df.columns = ['uniqueId', 'disbursedAmount', 'assetCost', 'itv', 'branchId',
'supplierId', 'manufacturerId', 'currentPincodeId', 'dateOfBirth',
'employmentType', 'disbursaldate', 'stateId', 'employeeCodeId',
'mobilenoAvlFlag', 'aadharFlag', 'panFlag', 'voteridFlag',
'drivingFlag', 'passportFlag', 'performCnsScore',
'performCnsScoreDescription', 'priNoOfAccts', 'priActiveAccts',
'priOverdueAccts', 'priCurrentBalance', 'priSanctionedAmount',
'priDisbursedAmount', 'secNoOfAccts', 'secActiveAccts',
'secOverdueAccts', 'secCurrentBalance', 'secSanctionedAmount',
'secDisbursedAmount', 'primaryInstalAmt', 'secInstalAmt',
'newAcctsInLastSixMonths', 'delinquentAcctsInLastSixMonths',
'averageAcctAge', 'creditHistoryLength', 'noOfInquiries',
'loanDefault']

# %%
df.isna().sum()
# Out:
# uniqueId                             0
# disbursedAmount                      0
# assetCost                            0
# itv                                  0
# branchId                             0
# supplierId                           0
# manufacturerId                       0
# currentPincodeId                     0
# dateOfBirth                          0
# employmentType                    7661
# disbursaldate                        0
# stateId                              0
# employeeCodeId                       0
# mobilenoAvlFlag                      0
# aadharFlag                           0
# panFlag                              0
# voteridFlag                          0
# drivingFlag                          0
# passportFlag                         0
# performCnsScore                      0
# performCnsScoreDescription           0
# priNoOfAccts                         0
# priActiveAccts                       0
# priOverdueAccts                      0
# priCurrentBalance                    0
# priSanctionedAmount                  0
# priDisbursedAmount                   0
# secNoOfAccts                         0
# secActiveAccts                       0
# secOverdueAccts                      0
# secCurrentBalance                    0
# secSanctionedAmount                  0
# secDisbursedAmount                   0
# primaryInstalAmt                     0
# secInstalAmt                         0
# newAcctsInLastSixMonths              0
# delinquentAcctsInLastSixMonths       0
# averageAcctAge                       0
# creditHistoryLength                  0
# noOfInquiries                        0
# loanDefault                          0
# dtype: int64

# %%
df.employmentType.value_counts()
# Out:
# Self employed    127635
# Salaried          97858
# Name: employmentType, dtype: int64

# %%
df.employmentType = df.employmentType.fillna("Unknown")

# %%
df.iloc[0]
# Out:
# uniqueId                                               420825
# disbursedAmount                                         50578
# assetCost                                               58400
# itv                                                     89.55
# branchId                                                   67
# supplierId                                              22807
# manufacturerId                                             45
# currentPincodeId                                         1441
# dateOfBirth                                          01-01-84
# employmentType                                       Salaried
# disbursaldate                                        03-08-18
# stateId                                                     6
# employeeCodeId                                           1998
# mobilenoAvlFlag                                             1
# aadharFlag                                                  1
# panFlag                                                     0
# voteridFlag                                                 0
# drivingFlag                                                 0
# passportFlag                                                0
# performCnsScore                                             0
# performCnsScoreDescription        No Bureau History Available
# priNoOfAccts                                                0
# priActiveAccts                                              0
# priOverdueAccts                                             0
# priCurrentBalance                                           0
# priSanctionedAmount                                         0
# priDisbursedAmount                                          0
# secNoOfAccts                                                0
# secActiveAccts                                              0
# secOverdueAccts                                             0
# secCurrentBalance                                           0
# secSanctionedAmount                                         0
# secDisbursedAmount                                          0
# primaryInstalAmt                                            0
# secInstalAmt                                                0
# newAcctsInLastSixMonths                                     0
# delinquentAcctsInLastSixMonths                              0
# averageAcctAge                                      0yrs 0mon
# creditHistoryLength                                 0yrs 0mon
# noOfInquiries                                               0
# loanDefault                                                 0
# Name: 0, dtype: object

# %%
df.averageAcctAge = df.averageAcctAge.apply(lambda x: float(str(re.search(r'\d+', x.split(" ")[0]).group()) + 
                        '.' + str(re.search(r'\d+', x.split(" ")[1]).group())))

# %%
df.creditHistoryLength = df.creditHistoryLength.apply(lambda x: float(str(re.search(r'\d+', x.split(" ")[0]).group()) + 
                        '.' + str(re.search(r'\d+', x.split(" ")[1]).group())))

# %%
df
# Out:
#         uniqueId  disbursedAmount  assetCost    itv  branchId  supplierId  \
# 0         420825            50578      58400  89.55        67       22807
# 1         537409            47145      65550  73.23        67       22807
# 2         417566            53278      61360  89.63        67       22807
# 3         624493            57513      66113  88.48        67       22807
# 4         539055            52378      60300  88.39        67       22807
# ...          ...              ...        ...    ...       ...         ...
# 233149    626432            63213     105405  60.72        34       20700
# 233150    606141            73651     100600  74.95        34       23775
# 233151    613658            33484      71212  48.45        77       22186
# 233152    548084            34259      73286  49.10        77       22186
# 233153    630213            75751     116009  66.81        77       22186
#
#         manufacturerId  currentPincodeId dateOfBirth employmentType  ...  \
# 0                   45              1441    01-01-84       Salaried  ...
# 1                   45              1502    31-07-85  Self employed  ...
# 2                   45              1497    24-08-85  Self employed  ...
# 3                   45              1501    30-12-93  Self employed  ...
# 4                   45              1495    09-12-77  Self employed  ...
# ...                ...               ...         ...            ...  ...
# 233149              48              1050    01-08-88       Salaried  ...
# 233150              51               990    05-12-88  Self employed  ...
# 233151              86              2299    01-06-76       Salaried  ...
# 233152              86              2299    26-03-94       Salaried  ...
# 233153              86              2299    18-02-84       Salaried  ...
#
#        secSanctionedAmount  secDisbursedAmount  primaryInstalAmt  \
# 0                        0                   0                 0
# 1                        0                   0              1991
# 2                        0                   0                 0
# 3                        0                   0                31
# 4                        0                   0                 0
# ...                    ...                 ...               ...
# 233149                   0                   0              4084
# 233150                   0                   0              1565
# 233151                   0                   0                 0
# 233152                   0                   0                 0
# 233153                   0                   0                 0
#
#         secInstalAmt  newAcctsInLastSixMonths  delinquentAcctsInLastSixMonths  \
# 0                  0                        0                               0
# 1                  0                        0                               1
# 2                  0                        0                               0
# 3                  0                        0                               0
# 4                  0                        0                               0
# ...              ...                      ...                             ...
# 233149             0                        0                               0
# 233150             0                        0                               0
# 233151             0                        0                               0
# 233152             0                        0                               0
# 233153             0                        0                               0
#
#         averageAcctAge  creditHistoryLength  noOfInquiries  loanDefault
# 0                 0.00                 0.00              0            0
# 1                 1.11                 1.11              0            1
# 2                 0.00                 0.00              0            0
# 3                 0.80                 1.30              1            1
# 4                 0.00                 0.00              1            1
# ...                ...                  ...            ...          ...
# 233149            1.90                 3.30              0            0
# 233150            0.60                 0.60              0            0
# 233151            0.00                 0.00              0            0
# 233152            0.00                 0.00              0            0
# 233153            0.00                 0.00              0            0
#
# [233154 rows x 41 columns]

# %%
temp = df.loanDefault
df = df.drop("loanDefault", axis = 1)
df.insert(0, 'loanDefault', temp)

# %%
df
# Out:
#         loanDefault  uniqueId  disbursedAmount  assetCost    itv  branchId  \
# 0                 0    420825            50578      58400  89.55        67
# 1                 1    537409            47145      65550  73.23        67
# 2                 0    417566            53278      61360  89.63        67
# 3                 1    624493            57513      66113  88.48        67
# 4                 1    539055            52378      60300  88.39        67
# ...             ...       ...              ...        ...    ...       ...
# 233149            0    626432            63213     105405  60.72        34
# 233150            0    606141            73651     100600  74.95        34
# 233151            0    613658            33484      71212  48.45        77
# 233152            0    548084            34259      73286  49.10        77
# 233153            0    630213            75751     116009  66.81        77
#
#         supplierId  manufacturerId  currentPincodeId dateOfBirth  ...  \
# 0            22807              45              1441    01-01-84  ...
# 1            22807              45              1502    31-07-85  ...
# 2            22807              45              1497    24-08-85  ...
# 3            22807              45              1501    30-12-93  ...
# 4            22807              45              1495    09-12-77  ...
# ...            ...             ...               ...         ...  ...
# 233149       20700              48              1050    01-08-88  ...
# 233150       23775              51               990    05-12-88  ...
# 233151       22186              86              2299    01-06-76  ...
# 233152       22186              86              2299    26-03-94  ...
# 233153       22186              86              2299    18-02-84  ...
#
#        secCurrentBalance secSanctionedAmount  secDisbursedAmount  \
# 0                      0                   0                   0
# 1                      0                   0                   0
# 2                      0                   0                   0
# 3                      0                   0                   0
# 4                      0                   0                   0
# ...                  ...                 ...                 ...
# 233149                 0                   0                   0
# 233150                 0                   0                   0
# 233151                 0                   0                   0
# 233152                 0                   0                   0
# 233153                 0                   0                   0
#
#         primaryInstalAmt  secInstalAmt  newAcctsInLastSixMonths  \
# 0                      0             0                        0
# 1                   1991             0                        0
# 2                      0             0                        0
# 3                     31             0                        0
# 4                      0             0                        0
# ...                  ...           ...                      ...
# 233149              4084             0                        0
# 233150              1565             0                        0
# 233151                 0             0                        0
# 233152                 0             0                        0
# 233153                 0             0                        0
#
#         delinquentAcctsInLastSixMonths  averageAcctAge  creditHistoryLength  \
# 0                                    0            0.00                 0.00
# 1                                    1            1.11                 1.11
# 2                                    0            0.00                 0.00
# 3                                    0            0.80                 1.30
# 4                                    0            0.00                 0.00
# ...                                ...             ...                  ...
# 233149                               0            1.90                 3.30
# 233150                               0            0.60                 0.60
# 233151                               0            0.00                 0.00
# 233152                               0            0.00                 0.00
# 233153                               0            0.00                 0.00
#
#         noOfInquiries
# 0                   0
# 1                   0
# 2                   0
# 3                   1
# 4                   1
# ...               ...
# 233149              0
# 233150              0
# 233151              0
# 233152              0
# 233153              0
#
# [233154 rows x 41 columns]

# %%
df.to_csv("vehicle_data.csv", index = False)

# %%
df_col = pd.read_csv("raw/data_dictionary.csv")

# %%
df_col = df_col.drop("Unnamed: 0", axis = 1)

# %%
df_col.insert(0, 'colName', ['uniqueId', 'loanDefault', 'disbursedAmount', 'assetCost', 'itv',
       'branchId', 'supplierId', 'manufacturerId', 'currentPincodeId',
       'dateOfBirth', 'employmentType', 'disbursaldate', 'stateId',
       'employeeCodeId', 'mobilenoAvlFlag', 'aadharFlag', 'panFlag',
       'voteridFlag', 'drivingFlag', 'passportFlag', 'performCnsScore',
       'performCnsScoreDescription', 'priNoOfAccts', 'priActiveAccts',
       'priOverdueAccts', 'priCurrentBalance', 'priSanctionedAmount',
       'priDisbursedAmount', 'secNoOfAccts', 'secActiveAccts',
       'secOverdueAccts', 'secCurrentBalance', 'secSanctionedAmount',
       'secDisbursedAmount', 'primaryInstalAmt', 'secInstalAmt',
       'newAcctsInLastSixMonths', 'delinquentAcctsInLastSixMonths',
       'averageAcctAge', 'creditHistoryLength', 'noOfInquiries'])

# %%
df_col = df_col.drop(["Variable Name", "Unnamed: 2"], axis = 1)

# %%
df_col.columns = 'colName', 'description'

# %%
df_col = df_col.reindex([1, 0] + list(range(2, 41))).reset_index(drop = True)

# %%
df_col['min'] = df.min().values
df_col['max'] = df.max().values

# %%
df_col
# Out:
#                            colName  \
# 0                      loanDefault
# 1                         uniqueId
# 2                  disbursedAmount
# 3                        assetCost
# 4                              itv
# 5                         branchId
# 6                       supplierId
# 7                   manufacturerId
# 8                 currentPincodeId
# 9                      dateOfBirth
# 10                  employmentType
# 11                   disbursaldate
# 12                         stateId
# 13                  employeeCodeId
# 14                 mobilenoAvlFlag
# 15                      aadharFlag
# 16                         panFlag
# 17                     voteridFlag
# 18                     drivingFlag
# 19                    passportFlag
# 20                 performCnsScore
# 21      performCnsScoreDescription
# 22                    priNoOfAccts
# 23                  priActiveAccts
# 24                 priOverdueAccts
# 25               priCurrentBalance
# 26             priSanctionedAmount
# 27              priDisbursedAmount
# 28                    secNoOfAccts
# 29                  secActiveAccts
# 30                 secOverdueAccts
# 31               secCurrentBalance
# 32             secSanctionedAmount
# 33              secDisbursedAmount
# 34                primaryInstalAmt
# 35                    secInstalAmt
# 36         newAcctsInLastSixMonths
# 37  delinquentAcctsInLastSixMonths
# 38                  averageAcctAge
# 39             creditHistoryLength
# 40                   noOfInquiries
#
#                                           description              min  \
# 0        Payment default in the first EMI on due date                0
# 1                            Identifier for customers           417428
# 2                            Amount of Loan disbursed            13320
# 3                                   Cost of the Asset            37000
# 4                          Loan to Value of the asset            10.03
# 5                 Branch where the loan was disbursed                1
# 6         Vehicle Dealer where the loan was disbursed            10524
# 7         Vehicle manufacturer(Hero, Honda, TVS etc.)               45
# 8                     Current pincode of the customer                1
# 9                       Date of birth of the customer         01-01-00
# 10  Employment Type of the customer (Salaried/Self...         Salaried
# 11                               Date of disbursement         01-08-18
# 12                              State of disbursement                1
# 13  Employee of the organization who logged the di...                1
# 14  if Mobile no. was shared by the customer then ...                1
# 15  if aadhar was shared by the customer then flag...                0
# 16  if pan was shared by the customer then flagged...                0
# 17  if voter  was shared by the customer then flag...                0
# 18  if DL was shared by the customer then flagged ...                0
# 19  if passport was shared by the customer then fl...                0
# 20                                       Bureau Score                0
# 21                           Bureau score description  A-Very Low Risk
# 22  count of total loans taken by the customer at ...                0
# 23  count of active loans taken by the customer at...                0
# 24  count of default accounts at the time of disbu...                0
# 25  total Principal outstanding amount of the acti...         -6678296
# 26  total amount that was sanctioned for all the l...                0
# 27  total amount that was disbursed for all the lo...                0
# 28  count of total loans taken by the customer at ...                0
# 29  count of active loans taken by the customer at...                0
# 30  count of default accounts at the time of disbu...                0
# 31  total Principal outstanding amount of the acti...          -574647
# 32  total amount that was sanctioned for all the l...                0
# 33  total amount that was disbursed for all the lo...                0
# 34                     EMI Amount of the primary loan                0
# 35                   EMI Amount of the secondary loan                0
# 36  New loans taken by the customer in last 6 mont...                0
# 37               Loans defaulted in the last 6 months                0
# 38                                Average loan tenure              0.0
# 39                              Time since first loan              0.0
# 40            Enquries done by the customer for loans                0
#
#                                              max
# 0                                              1
# 1                                         671084
# 2                                         990572
# 3                                        1628992
# 4                                           95.0
# 5                                            261
# 6                                          24803
# 7                                            156
# 8                                           7345
# 9                                       31-12-99
# 10                                       Unknown
# 11                                      31-10-18
# 12                                            22
# 13                                          3795
# 14                                             1
# 15                                             1
# 16                                             1
# 17                                             1
# 18                                             1
# 19                                             1
# 20                                           890
# 21  Not Scored: Sufficient History Not Available
# 22                                           453
# 23                                           144
# 24                                            25
# 25                                      96524920
# 26                                    1000000000
# 27                                    1000000000
# 28                                            52
# 29                                            36
# 30                                             8
# 31                                      36032852
# 32                                      30000000
# 33                                      30000000
# 34                                      25642806
# 35                                       4170901
# 36                                            35
# 37                                            20
# 38                                          30.9
# 39                                          39.0
# 40                                            36

# %%
df_col.to_csv("vehicle_info.csv", index = False)

# %%
df_col
# Out:
#                            colName  \
# 0                      loanDefault
# 1                         uniqueId
# 2                  disbursedAmount
# 3                        assetCost
# 4                              itv
# 5                         branchId
# 6                       supplierId
# 7                   manufacturerId
# 8                 currentPincodeId
# 9                      dateOfBirth
# 10                  employmentType
# 11                   disbursaldate
# 12                         stateId
# 13                  employeeCodeId
# 14                 mobilenoAvlFlag
# 15                      aadharFlag
# 16                         panFlag
# 17                     voteridFlag
# 18                     drivingFlag
# 19                    passportFlag
# 20                 performCnsScore
# 21      performCnsScoreDescription
# 22                    priNoOfAccts
# 23                  priActiveAccts
# 24                 priOverdueAccts
# 25               priCurrentBalance
# 26             priSanctionedAmount
# 27              priDisbursedAmount
# 28                    secNoOfAccts
# 29                  secActiveAccts
# 30                 secOverdueAccts
# 31               secCurrentBalance
# 32             secSanctionedAmount
# 33              secDisbursedAmount
# 34                primaryInstalAmt
# 35                    secInstalAmt
# 36         newAcctsInLastSixMonths
# 37  delinquentAcctsInLastSixMonths
# 38                  averageAcctAge
# 39             creditHistoryLength
# 40                   noOfInquiries
#
#                                           description              min  \
# 0        Payment default in the first EMI on due date                0
# 1                            Identifier for customers           417428
# 2                            Amount of Loan disbursed            13320
# 3                                   Cost of the Asset            37000
# 4                          Loan to Value of the asset            10.03
# 5                 Branch where the loan was disbursed                1
# 6         Vehicle Dealer where the loan was disbursed            10524
# 7         Vehicle manufacturer(Hero, Honda, TVS etc.)               45
# 8                     Current pincode of the customer                1
# 9                       Date of birth of the customer         01-01-00
# 10  Employment Type of the customer (Salaried/Self...         Salaried
# 11                               Date of disbursement         01-08-18
# 12                              State of disbursement                1
# 13  Employee of the organization who logged the di...                1
# 14  if Mobile no. was shared by the customer then ...                1
# 15  if aadhar was shared by the customer then flag...                0
# 16  if pan was shared by the customer then flagged...                0
# 17  if voter  was shared by the customer then flag...                0
# 18  if DL was shared by the customer then flagged ...                0
# 19  if passport was shared by the customer then fl...                0
# 20                                       Bureau Score                0
# 21                           Bureau score description  A-Very Low Risk
# 22  count of total loans taken by the customer at ...                0
# 23  count of active loans taken by the customer at...                0
# 24  count of default accounts at the time of disbu...                0
# 25  total Principal outstanding amount of the acti...         -6678296
# 26  total amount that was sanctioned for all the l...                0
# 27  total amount that was disbursed for all the lo...                0
# 28  count of total loans taken by the customer at ...                0
# 29  count of active loans taken by the customer at...                0
# 30  count of default accounts at the time of disbu...                0
# 31  total Principal outstanding amount of the acti...          -574647
# 32  total amount that was sanctioned for all the l...                0
# 33  total amount that was disbursed for all the lo...                0
# 34                     EMI Amount of the primary loan                0
# 35                   EMI Amount of the secondary loan                0
# 36  New loans taken by the customer in last 6 mont...                0
# 37               Loans defaulted in the last 6 months                0
# 38                                Average loan tenure              0.0
# 39                              Time since first loan              0.0
# 40            Enquries done by the customer for loans                0
#
#                                              max
# 0                                              1
# 1                                         671084
# 2                                         990572
# 3                                        1628992
# 4                                           95.0
# 5                                            261
# 6                                          24803
# 7                                            156
# 8                                           7345
# 9                                       31-12-99
# 10                                       Unknown
# 11                                      31-10-18
# 12                                            22
# 13                                          3795
# 14                                             1
# 15                                             1
# 16                                             1
# 17                                             1
# 18                                             1
# 19                                             1
# 20                                           890
# 21  Not Scored: Sufficient History Not Available
# 22                                           453
# 23                                           144
# 24                                            25
# 25                                      96524920
# 26                                    1000000000
# 27                                    1000000000
# 28                                            52
# 29                                            36
# 30                                             8
# 31                                      36032852
# 32                                      30000000
# 33                                      30000000
# 34                                      25642806
# 35                                       4170901
# 36                                            35
# 37                                            20
# 38                                          30.9
# 39                                          39.0
# 40                                            36
